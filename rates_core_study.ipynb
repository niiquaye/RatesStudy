# %% [markdown]
# [Duration](https://www.blackrock.com/us/individual/education/understanding-duration)
#  - How long it takes to get coupon payments and return of principle
#  - The higher the duration of a bond the more its price will drop
#  - Bonds price increases or decreases 1% for every year of duration
#      - (i.e. if bond has a duration of 5 yrs and interest rates fall by 1% the bonds price will go down by ~5%)
#      - If you expect rates to rise - get shorter duration bonds vice versa

# %% [markdown]
# [Yield to Maturity](https://www.investopedia.com/terms/y/yieldtomaturity.asp)
# - Total rate of return that will have been earned by a bond when it makes all interest payments and repays the original principal
# - Internal rate of return of the bond - assumes all coupon/interest payments are reinvested
# - Differs from a bonds coupon rate (annual amount of interest that a bond owner receives)
# - High YTM might indicate bargain opportunity
# - If YTM > Coupon Rate then bond being sold at a discount else bond being sold at a premium
# - Variations of YTM
#     - Yield to Call: bond can be repurchased by issuer before reaching maturity, thus shorter cashflow
#     - Yield to Put: bond will be sold back to issuer at a fixed price
#     - Yield to Worst: when a bond can have calls or puts - calculate YTW that gives lowest yield

# %% [markdown]
# [Inverted Yield Curve](https://www.investopedia.com/terms/i/invertedyieldcurve.asp)
# - Long-term interest rates are less than short-term interest rates
# - Reliable indiactor of a recession
# - implies investors are taking money away from short-term bonds and into long-term bonds
# - Suggests the market as a whole is becoming more economic pessimistic about prospects in the near future

# %% [markdown]
# Treasury Futures
# - [bond futures on US Treasury](https://www.investopedia.com/terms/b/bondfutures.asp)
#     - Financial derivative that obligates the contract holder to purchase/sell a bond at a specific price and date
# - Allows for speculation on interest rates
# - only available on 2-5-10-30 yr bonds (very liquid / trades 24hrs a day)
# - Used to hedge against changes on interest rates
# - Price of Treasury Futures is inverse to the yield of a treasury bond
# - Used to speculate on treasury or hedge treasury holdings
# - Underlying: [US Treasury](https://www.investopedia.com/terms/t/treasurybond.asp)
#     - government debt security (soverign debt) used to finance government
#     - Maturity of 20 or 30 yrs
#     - pay semiannual interest payments till maturity
# - I.e. if lets say an asian country increases interest rates this can have a negative ripple on US Treasuries

# %% [markdown]
# [Treasury Futures Duration](https://www.financestrategists.com/wealth-management/bonds/treasury-bills-vs-bonds-vs-notes/)
# - Futures available only for 2, 5, 10, 30 yr duration
# - Treasury Bonds Durations: 20, 30yr (more risky, so higher yield)
# - Treasury Bills Duration: (4 weeks, 13 weeks, 26 weeks 52 weeks) less than a 1 year (do not pay interest to holder)
#     - Rather they are issued at a discount to face value - profit is made from difference from discounted bond and face value
# - Treasury Notes Duration: (intermediate) 2, 3, 5, 7, 10 yrs - semiannual interest payments

# %% [markdown]
# [Inflation](https://corporatefinanceinstitute.com/resources/derivatives/inflation-swap/) & Vanilla Swaps
# - Vanilla Swap: an OTC derivative product that allows two counterparties to exchange cash flow
#                 one cash flow is typically fixed whilst one is variable (i.e. interest rate swaps)
# - Inflation Swaps: used to transfer inflation risk from one party to another through exchange of cash flows
# - The party looking to hedge their inflation risk pays a floating rate linked to an inflation index - like the CPI
# ![image.png](attachment:image.png)

# %% [markdown]
# Feds Funds Futures
# - Fed Funds: Bank reserves at the Federal Reserve
# - Cash settled
# - Fed Funds Futures are based on the EFFR (Effective Fed Funds Rate)
#     - EFFR: daily rate at which banks can loan out money to each other
# - What affects the Feds Fund Futures: FOMC (Federal Open Market Committee) sets the target for fed fund rate, inflation, employment stats

# %% [markdown]
# [End of Month Rebalancing](https://www.forexlive.com/Education/!/how-month-end-rebalancing-works-20191128)
# - Portfolio Managers rebalance their portfolio at the end of the month to meet hedge ratios
#     - Typically done at 4pm London fix on the last trading day of the month
# - Can provide insight into how assets have changed over the course of a month

# %% [markdown]
# Compositon of Credit ETFs
# - [HYG](https://www.ishares.com/us/products/239565/ishares-iboxx-high-yield-corporate-bond-etf): high yield corporate bond ETF ($73.10)
#     - FORD
#     - SIRIUS XM Radio
#     - TENET Healthcare
# - [LQD](https://www.ishares.com/us/products/239566/ishares-iboxx-investment-grade-corporate-bond-etf): US Investment Grade Corporate Bonds ($101.82)
#     - JP Morgan Chase
#     - Morgan Stanely
#     - Goldman Sachs
# - [EMB](https://www.ishares.com/us/products/239572/ishares-jp-morgan-usd-emerging-markets-bond-etf): JP Morgan Emerging Markets/Soverign Debt/Exposure to US Denominated government bonds issued by emerging market countries ($81.53)
#     - Turkey
#     - Phillipines
#     - Brazil

# %% [markdown]
# [Treasuries Hedging & Risk Management](https://www.youtube.com/watch?v=CLYQU8wWVFs)
# 1. Identify Futures contract with cheapest to deliver security
# 2. Determine contracts implied basis point value (BPV or DV01 - Dollar Value of an O1)
#     - BPV/DV01
#         - The financial change of a security or 0.01% change in yield
# 3. BPV Contract = [BPV of cheapest to deliver contract] / [conversion factor]
# 4. BPV Risk (value at risk per contract)
# 5. Hedge Ratio = [BPV Risk] / [BPV Contract]
